# %%
#install the required packages
#pip install requests
#pip install ipywidgets

# %%
#import the required packages
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# %%
#website with data and api information
#https://data.cdc.gov/NCHS/Provisional-COVID-19-Death-Counts-by-Week-Ending-D/r8kw-7aab/about_data

#initial API url
api_url = 'https://data.cdc.gov/resource/r8kw-7aab.json'
api_response = requests.get(api_url)

#check that api is working
#'200' is good
print(api_response.status_code)
# Out:
# 200

# %%
#view data in a json format
json_data = api_response.json()
print(json_data[:3])
# Out:
# [{'data_as_of': '2025-02-06T00:00:00.000', 'start_date': '2019-12-29T00:00:00.000', 'end_date': '2020-01-04T00:00:00.000', 'group': 'By Week', 'year': '2019/2020', 'mmwr_week': '1', 'week_ending_date': '2020-01-04T00:00:00.000', 'state': 'United States', 'covid_19_deaths': '0', 'total_deaths': '60170', 'percent_of_expected_deaths': '98.00', 'pneumonia_deaths': '4111', 'pneumonia_and_covid_19_deaths': '0', 'influenza_deaths': '434', 'pneumonia_influenza_or_covid_19_deaths': '4545'}, {'data_as_of': '2025-02-06T00:00:00.000', 'start_date': '2020-01-05T00:00:00.000', 'end_date': '2020-01-11T00:00:00.000', 'group': 'By Week', 'year': '2020', 'mmwr_week': '2', 'week_ending_date': '2020-01-11T00:00:00.000', 'state': 'United States', 'covid_19_deaths': '1', 'total_deaths': '60734', 'percent_of_expected_deaths': '97.00', 'pneumonia_deaths': '4153', 'pneumonia_and_covid_19_deaths': '1', 'influenza_deaths': '475', 'pneumonia_influenza_or_covid_19_deaths': '4628'}, {'data_as_of': '2025-02-06T00:00:00.000', 'start_date': '2020-01-12T00:00:00.000', 'end_date': '2020-01-18T00:00:00.000', 'group': 'By Week', 'year': '2020', 'mmwr_week': '3', 'week_ending_date': '2020-01-18T00:00:00.000', 'state': 'United States', 'covid_19_deaths': '2', 'total_deaths': '59362', 'percent_of_expected_deaths': '98.00', 'pneumonia_deaths': '4066', 'pneumonia_and_covid_19_deaths': '2', 'influenza_deaths': '468', 'pneumonia_influenza_or_covid_19_deaths': '4534'}]

# %%
#put json data in pandas datafram for better viewing and analyis
usa_df = pd.DataFrame(json_data)
usa_df[:5]
# Out:
#                 data_as_of               start_date                 end_date  \
# 0  2025-02-06T00:00:00.000  2019-12-29T00:00:00.000  2020-01-04T00:00:00.000
# 1  2025-02-06T00:00:00.000  2020-01-05T00:00:00.000  2020-01-11T00:00:00.000
# 2  2025-02-06T00:00:00.000  2020-01-12T00:00:00.000  2020-01-18T00:00:00.000
# 3  2025-02-06T00:00:00.000  2020-01-19T00:00:00.000  2020-01-25T00:00:00.000
# 4  2025-02-06T00:00:00.000  2020-01-26T00:00:00.000  2020-02-01T00:00:00.000
#
#      group       year mmwr_week         week_ending_date          state  \
# 0  By Week  2019/2020         1  2020-01-04T00:00:00.000  United States
# 1  By Week       2020         2  2020-01-11T00:00:00.000  United States
# 2  By Week       2020         3  2020-01-18T00:00:00.000  United States
# 3  By Week       2020         4  2020-01-25T00:00:00.000  United States
# 4  By Week       2020         5  2020-02-01T00:00:00.000  United States
#
#   covid_19_deaths total_deaths percent_of_expected_deaths pneumonia_deaths  \
# 0               0        60170                      98.00             4111
# 1               1        60734                      97.00             4153
# 2               2        59362                      98.00             4066
# 3               3        59162                      99.00             3915
# 4               0        58834                      99.00             3818
#
#   pneumonia_and_covid_19_deaths influenza_deaths  \
# 0                             0              434
# 1                             1              475
# 2                             2              468
# 3                             0              500
# 4                             0              481
#
#   pneumonia_influenza_or_covid_19_deaths footnote
# 0                                   4545      NaN
# 1                                   4628      NaN
# 2                                   4534      NaN
# 3                                   4418      NaN
# 4                                   4299      NaN

# %%
#drop first column, 'data_as_of' not needed
usa_df.drop(columns=['data_as_of', 'mmwr_week', 'week_ending_date'], axis=1, inplace=True)
usa_df[:5]
# Out:
#                 start_date                 end_date    group       year  \
# 0  2019-12-29T00:00:00.000  2020-01-04T00:00:00.000  By Week  2019/2020
# 1  2020-01-05T00:00:00.000  2020-01-11T00:00:00.000  By Week       2020
# 2  2020-01-12T00:00:00.000  2020-01-18T00:00:00.000  By Week       2020
# 3  2020-01-19T00:00:00.000  2020-01-25T00:00:00.000  By Week       2020
# 4  2020-01-26T00:00:00.000  2020-02-01T00:00:00.000  By Week       2020
#
#            state covid_19_deaths total_deaths percent_of_expected_deaths  \
# 0  United States               0        60170                      98.00
# 1  United States               1        60734                      97.00
# 2  United States               2        59362                      98.00
# 3  United States               3        59162                      99.00
# 4  United States               0        58834                      99.00
#
#   pneumonia_deaths pneumonia_and_covid_19_deaths influenza_deaths  \
# 0             4111                             0              434
# 1             4153                             1              475
# 2             4066                             2              468
# 3             3915                             0              500
# 4             3818                             0              481
#
#   pneumonia_influenza_or_covid_19_deaths footnote
# 0                                   4545      NaN
# 1                                   4628      NaN
# 2                                   4534      NaN
# 3                                   4418      NaN
# 4                                   4299      NaN

# %%
#create function to format the date data
def short_date(date):
    index = date.find('T')

    new_date = date[:index]

    return new_date

usa_df['start_date'] = usa_df['start_date'].apply(short_date)
usa_df['end_date'] = usa_df['end_date'].apply(short_date)

usa_df[:5]
# Out:
#    start_date    end_date    group       year          state covid_19_deaths  \
# 0  2019-12-29  2020-01-04  By Week  2019/2020  United States               0
# 1  2020-01-05  2020-01-11  By Week       2020  United States               1
# 2  2020-01-12  2020-01-18  By Week       2020  United States               2
# 3  2020-01-19  2020-01-25  By Week       2020  United States               3
# 4  2020-01-26  2020-02-01  By Week       2020  United States               0
#
#   total_deaths percent_of_expected_deaths pneumonia_deaths  \
# 0        60170                      98.00             4111
# 1        60734                      97.00             4153
# 2        59362                      98.00             4066
# 3        59162                      99.00             3915
# 4        58834                      99.00             3818
#
#   pneumonia_and_covid_19_deaths influenza_deaths  \
# 0                             0              434
# 1                             1              475
# 2                             2              468
# 3                             0              500
# 4                             0              481
#
#   pneumonia_influenza_or_covid_19_deaths footnote
# 0                                   4545      NaN
# 1                                   4628      NaN
# 2                                   4534      NaN
# 3                                   4418      NaN
# 4                                   4299      NaN

# %%
#remove unessential columns
usa_df = usa_df.drop(columns=['group', 'state', 'footnote'])
usa_df[:5]
# Out:
#    start_date    end_date       year covid_19_deaths total_deaths  \
# 0  2019-12-29  2020-01-04  2019/2020               0        60170
# 1  2020-01-05  2020-01-11       2020               1        60734
# 2  2020-01-12  2020-01-18       2020               2        59362
# 3  2020-01-19  2020-01-25       2020               3        59162
# 4  2020-01-26  2020-02-01       2020               0        58834
#
#   percent_of_expected_deaths pneumonia_deaths pneumonia_and_covid_19_deaths  \
# 0                      98.00             4111                             0
# 1                      97.00             4153                             1
# 2                      98.00             4066                             2
# 3                      99.00             3915                             0
# 4                      99.00             3818                             0
#
#   influenza_deaths pneumonia_influenza_or_covid_19_deaths
# 0              434                                   4545
# 1              475                                   4628
# 2              468                                   4534
# 3              500                                   4418
# 4              481                                   4299

# %%
# 'usa_df' is the df I will work from to create other specific tables and queries

# %%
#extract month from 'start_date' column for easier grouping and quering
def find_month(date):

    date = str(date)

    month = date[5:7]

    return month

usa_df['month'] = usa_df['start_date'].apply(find_month)
usa_df[:5]
# Out:
#    start_date    end_date       year covid_19_deaths total_deaths  \
# 0  2019-12-29  2020-01-04  2019/2020               0        60170
# 1  2020-01-05  2020-01-11       2020               1        60734
# 2  2020-01-12  2020-01-18       2020               2        59362
# 3  2020-01-19  2020-01-25       2020               3        59162
# 4  2020-01-26  2020-02-01       2020               0        58834
#
#   percent_of_expected_deaths pneumonia_deaths pneumonia_and_covid_19_deaths  \
# 0                      98.00             4111                             0
# 1                      97.00             4153                             1
# 2                      98.00             4066                             2
# 3                      99.00             3915                             0
# 4                      99.00             3818                             0
#
#   influenza_deaths pneumonia_influenza_or_covid_19_deaths month
# 0              434                                   4545    12
# 1              475                                   4628    01
# 2              468                                   4534    01
# 3              500                                   4418    01
# 4              481                                   4299    01

# %%
#get data from specific Year
def get_year(year):

    year = str(year)

    year_df = usa_df[usa_df['year'] == year]

    return year_df

get_year(2023)
# Out:
#      start_date    end_date  year covid_19_deaths total_deaths  \
# 157  2023-01-01  2023-01-07  2023            3881        69192
# 158  2023-01-08  2023-01-14  2023            3698        66548
# 159  2023-01-15  2023-01-21  2023            3263        64369
# 160  2023-01-22  2023-01-28  2023            2919        62609
# 161  2023-01-29  2023-02-04  2023            2648        62942
# ..          ...         ...   ...             ...          ...
# 995  2023-10-08  2023-10-14  2023              30         1281
# 996  2023-10-15  2023-10-21  2023              37         1291
# 997  2023-10-22  2023-10-28  2023              35         1260
# 998  2023-10-29  2023-11-04  2023              31         1291
# 999  2023-11-05  2023-11-11  2023              30         1312
#
#     percent_of_expected_deaths pneumonia_deaths pneumonia_and_covid_19_deaths  \
# 157                     112.00             5527                          1439
# 158                     107.00             5210                          1406
# 159                     106.00             5037                          1276
# 160                     105.00             4613                          1086
# 161                     106.00             4493                           953
# ..                         ...              ...                           ...
# 995                      120.0               74                            13
# 996                     118.00               63                            15
# 997                     121.00               64                            12
# 998                      120.0               63                            13
# 999                     116.00               66                            12
#
#     influenza_deaths pneumonia_influenza_or_covid_19_deaths month
# 157              891                                   8800    01
# 158              629                                   8084    01
# 159              388                                   7381    01
# 160              274                                   6700    01
# 161              145                                   6310    01
# ..               ...                                    ...   ...
# 995                0                                     91    10
# 996              NaN                                     88    10
# 997                0                                     87    10
# 998              NaN                                     82    10
# 999              NaN                                     85    11
#
# [201 rows x 11 columns]

# %%
#convert 'start_date' and 'end_date' to datetime data type
usa_df['start_date'] = pd.to_datetime(usa_df['start_date'])

usa_df['end_date'] = pd.to_datetime(usa_df['end_date'])

# %%
#combine month and year columns into one and delete individual columns
#combine month and year columns into one and delete individual columns

def month_year(month, year):

    combined_date = month + '-' + year

    return combined_date

usa_df['month_date'] = usa_df.apply(lambda row: month_year(row['month'], row['year']), axis=1)
usa_df
# Out:
#     start_date   end_date       year covid_19_deaths total_deaths  \
# 0   2019-12-29 2020-01-04  2019/2020               0        60170
# 1   2020-01-05 2020-01-11       2020               1        60734
# 2   2020-01-12 2020-01-18       2020               2        59362
# 3   2020-01-19 2020-01-25       2020               3        59162
# 4   2020-01-26 2020-02-01       2020               0        58834
# ..         ...        ...        ...             ...          ...
# 995 2023-10-08 2023-10-14       2023              30         1281
# 996 2023-10-15 2023-10-21       2023              37         1291
# 997 2023-10-22 2023-10-28       2023              35         1260
# 998 2023-10-29 2023-11-04       2023              31         1291
# 999 2023-11-05 2023-11-11       2023              30         1312
#
#     percent_of_expected_deaths pneumonia_deaths pneumonia_and_covid_19_deaths  \
# 0                        98.00             4111                             0
# 1                        97.00             4153                             1
# 2                        98.00             4066                             2
# 3                        99.00             3915                             0
# 4                        99.00             3818                             0
# ..                         ...              ...                           ...
# 995                      120.0               74                            13
# 996                     118.00               63                            15
# 997                     121.00               64                            12
# 998                      120.0               63                            13
# 999                     116.00               66                            12
#
#     influenza_deaths pneumonia_influenza_or_covid_19_deaths month  \
# 0                434                                   4545    12
# 1                475                                   4628    01
# 2                468                                   4534    01
# 3                500                                   4418    01
# 4                481                                   4299    01
# ..               ...                                    ...   ...
# 995                0                                     91    10
# 996              NaN                                     88    10
# 997                0                                     87    10
# 998              NaN                                     82    10
# 999              NaN                                     85    11
#
#        month_date
# 0    12-2019/2020
# 1         01-2020
# 2         01-2020
# 3         01-2020
# 4         01-2020
# ..            ...
# 995       10-2023
# 996       10-2023
# 997       10-2023
# 998       10-2023
# 999       11-2023
#
# [1000 rows x 12 columns]

# %%
unique_years = list(set(list(usa_df.get('year'))))
cause_of_death = list(usa_df.columns)[3:10]

# %%
import ipywidgets as widgets
from IPython.display import display


#create dropdown for yr
dropdown_yr = widgets.Dropdown(
    options=unique_years,
    value='2024',
    description='Choose 1st Year:'
)

dropdown_yr.style.description_width = 'initial'

#create dropdown for yr
dropdown_yr2 = widgets.Dropdown(
    options=unique_years + ['None'],
    value='2024',
    description='Choose 2nd Year:'
)

dropdown_yr2.style.description_width = 'initial'

#create dropdown for cod
dropdown_cod = widgets.Dropdown(
    options=cause_of_death,
    value='covid_19_deaths',
    description='Cause of Death:',
    disabled=False
)

dropdown_cod.style.description_width = 'initial'

#create submit button widget
submit_button = widgets.Button(description='Submit')

#output widget to display outcome
output = widgets.Output()

#function to print output based on dropdown value
def choose_yr_cod(value):
    with output:
        output.clear_output()
        selected_yr = dropdown_yr.value
        selected_cod = dropdown_cod.value
        selected_yr2 = dropdown_yr2.value

        if selected_yr2 == 'None':
        
            #filter for year
            year = str(selected_yr)
            new_df = (usa_df[usa_df['year'] == year]
                      .drop(columns=['start_date', 'end_date', 'month_date', 'year'])
                      .fillna(0)
                      .astype(float)
                      .astype(int)
                     )

            #combine on month
            newer_df = new_df.groupby('month').sum()

            #create line graph 
            line_gr = newer_df.plot(kind='line', y=selected_cod, title='Deaths Per Month', marker='o')

            plt.show(line_gr)

        else:

            year1 = str(selected_yr)
            year2 = str(selected_yr2)

            #create first dataframe
            new_df1 = (usa_df[(usa_df['year'] == year1)]
                      .drop(columns=['start_date', 'end_date', 'month_date', 'year'])
                      .fillna(0)
                      .astype(float)
                      .astype(int)
                     )

            newer_df1 = new_df1.groupby('month').sum()


            #create second dataframe
            new_df2 = (usa_df[(usa_df['year'] == year2)]
                      .drop(columns=['start_date', 'end_date', 'month_date', 'year'])
                      .fillna(0)
                      .astype(float)
                      .astype(int)
                     )

            newer_df2 = new_df2.groupby('month').sum()

            #Plot the first dataset
            plt.plot(newer_df1[selected_cod], label=year1, color='blue', marker='o')

            #Plot the second dataset
            plt.plot(newer_df2[selected_cod], label=year2, color='green', marker='o')  

            #customize plt
            plt.title(selected_cod + ' ' + year1 + ' and ' + year2)
            plt.xlabel('Month')
            plt.ylabel('Number of Deaths')
            plt.legend()

            #display plt
            plt.show()


#attach button to function above
submit_button.on_click(choose_yr_cod)

#create horizontal box to house widgets
title = widgets.HTML('<H2>Track and Compare Covid and Covid-Like Death Counts by Year<H2>')
description = widgets.HTML('<p>Select None for the second dropdown if comparison is not needed<p>')
year_selection = widgets.HBox([dropdown_yr, dropdown_yr2])
cod_selection = widgets.HBox([dropdown_cod])
spacer = widgets.HTML('<br>')

#display all widgets
display(
    
    title,  
    description,
    year_selection, 
    spacer, 
    cod_selection, 
    spacer, 
    submit_button, 
    output

)
# Out:
# HTML(value='<H2>Track and Compare Covid and Covid-Like Death Counts by Year<H2>')
# HTML(value='<p>Select None for the second dropdown if comparison is not needed<p>')
# HBox(children=(Dropdown(description='Choose 1st Year:', index=6, options=('2023', '2025', '2021', '2019/2020',…
# HTML(value='<br>')
# HBox(children=(Dropdown(description='Cause of Death:', options=('covid_19_deaths', 'total_deaths', 'percent_of…
# HTML(value='<br>')
# Button(description='Submit', style=ButtonStyle())
# Output()
