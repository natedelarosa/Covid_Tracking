# %%
#install the required packages
pip install requests
# Out:
#   Cell In[1], line 2
#     pip install requests
#         ^
# SyntaxError: invalid syntax

# %%
#import the required packages
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import panel as pn
pn.extension()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='06e038a1-a5c0-4c06-8100-eb032c299029'>
#   <div id="d0021c9a-51e5-45fc-ba55-1d1f2035c968" data-root-id="06e038a1-a5c0-4c06-8100-eb032c299029" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
#initial API url
api_url = 'https://data.cdc.gov/resource/r8kw-7aab.json'
api_response = requests.get(api_url)

#check that api is working
#'200' is good
print(api_response.status_code)
# Out:
# 200

# %%
#view data in a json format
json_data = api_response.json()
print(json_data[:3])
# Out:
# [{'data_as_of': '2024-10-31T00:00:00.000', 'start_date': '2019-12-29T00:00:00.000', 'end_date': '2020-01-04T00:00:00.000', 'group': 'By Week', 'year': '2019/2020', 'mmwr_week': '1', 'week_ending_date': '2020-01-04T00:00:00.000', 'state': 'United States', 'covid_19_deaths': '0', 'total_deaths': '60170', 'percent_of_expected_deaths': '98.00', 'pneumonia_deaths': '4111', 'pneumonia_and_covid_19_deaths': '0', 'influenza_deaths': '434', 'pneumonia_influenza_or_covid_19_deaths': '4545'}, {'data_as_of': '2024-10-31T00:00:00.000', 'start_date': '2020-01-05T00:00:00.000', 'end_date': '2020-01-11T00:00:00.000', 'group': 'By Week', 'year': '2020', 'mmwr_week': '2', 'week_ending_date': '2020-01-11T00:00:00.000', 'state': 'United States', 'covid_19_deaths': '1', 'total_deaths': '60734', 'percent_of_expected_deaths': '97.00', 'pneumonia_deaths': '4153', 'pneumonia_and_covid_19_deaths': '1', 'influenza_deaths': '475', 'pneumonia_influenza_or_covid_19_deaths': '4628'}, {'data_as_of': '2024-10-31T00:
# ...

# %%
#put json data in pandas datafram for better viewing and analyis
usa_df = pd.DataFrame(json_data)
usa_df[:5]
# Out:
#                 data_as_of               start_date                 end_date  \
# 0  2024-10-31T00:00:00.000  2019-12-29T00:00:00.000  2020-01-04T00:00:00.000
# 1  2024-10-31T00:00:00.000  2020-01-05T00:00:00.000  2020-01-11T00:00:00.000
# 2  2024-10-31T00:00:00.000  2020-01-12T00:00:00.000  2020-01-18T00:00:00.000
# 3  2024-10-31T00:00:00.000  2020-01-19T00:00:00.000  2020-01-25T00:00:00.000
# 4  2024-10-31T00:00:00.000  2020-01-26T00:00:00.000  2020-02-01T00:00:00.000
#
#      group       year mmwr_week         week_ending_date          state  \
# 0  By Week  2019/2020         1  2020-01-04T00:00:00.000  United States
# 1  By Week       2020         2  2020-01-11T00:00:00.000  United States
# 2  By Week       2020         3  2020-01-18T00:00:00.000  United States
# 3  By Week       2020         4  2020-01-25T00:00:00.000  United States
# 4  By Week       2020         5  2020-02-01T00:00:00.000  United States
#
# ...

# %%
# Function to create a plot based on a given value
def create_plot(value):
    # Generate some data
    x = np.linspace(0, 10, 100)
    y = np.sin(x + value)  # Modify the sine wave based on the slider value

    # Create the plot
    plt.figure(figsize=(8, 4))
    plt.plot(x, y)
    plt.title('Sine Wave')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.grid()
    
    # Return the figure
    plt.close()  # Prevents automatic display in the notebook
    return plt

# Slider widget
slider = pn.widgets.FloatSlider(name='Phase Shift', start=0, end=10, step=0.1)

# Panel to update the plot when the slider changes
@pn.depends(slider)
def update_plot(value):
    return create_plot(value)  # Create a new plot

# Create a dashboard layout
dashboard = pn.Column(slider, pn.panel(update_plot))

# Display the dashboard
dashboard.servable()
# Out:
# Column
#     [0] FloatSlider(end=10, name='Phase Shift')
#     [1] ParamFunction(function, _pane=Str, defer_load=False)
