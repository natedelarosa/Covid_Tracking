# %%
#install the required packages
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\nated\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nated\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nated\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nated\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nated\anaconda3\lib\site-packages (from requests) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
#import the required packages
import requests
import json
import pandas as pd

# %%
#initial API url
api_url = '	https://www.healthit.gov/data/open-api?source=Surescripts_04-2014_State.csv'
api_response = requests.get(api_url)

#check that api is working
#'200' is good
print(api_response.status_code)
# Out:
# 200

# %%
#view data in a json format
json_data = api_response.json()
print(json_data)
# Out:
# [{'region': 'National', 'region_code': 'US', 'period': '2008', 'tot_e_Rx': '', 'tot_e_Rx_thru_ehr': '', 'tot_e_Rx_thru_stand_alone': '', 'tot_primary_care_e_Rx': '', 'tot_non_primary_care_e_Rx': '', 'tot_nurse_prac_e_Rx': '', 'tot_phys_asst_e_Rx': '', 'pct_new_renewal_e_Rx': '0.04', 'tot_med_hist_reqs': '', 'tot_med_hist_req_resps': '', 'pct_pharm_enabled': '', 'pct_pharm_e_Rx': ''}, {'region': 'National', 'region_code': 'US', 'period': '2009', 'tot_e_Rx': '', 'tot_e_Rx_thru_ehr': '', 'tot_e_Rx_thru_stand_alone': '', 'tot_primary_care_e_Rx': '', 'tot_non_primary_care_e_Rx': '', 'tot_nurse_prac_e_Rx': '', 'tot_phys_asst_e_Rx': '', 'pct_new_renewal_e_Rx': '0.11', 'tot_med_hist_reqs': '', 'tot_med_hist_req_resps': '', 'pct_pharm_enabled': '', 'pct_pharm_e_Rx': ''}, {'region': 'National', 'region_code': 'US', 'period': '2010', 'tot_e_Rx': '', 'tot_e_Rx_thru_ehr': '', 'tot_e_Rx_thru_stand_alone': '', 'tot_primary_care_e_Rx': '', 'tot_non_primary_care_e_Rx': '', 'tot_nurse_prac_e_Rx': '', 'tot_phys_asst_e_Rx': '', 'pct_new_renewal_e_Rx': '0.19', 'tot_med_hist_reqs': '', 'tot_med_hist_req_resps': '', 'pct_pharm_enabled': '', 'pct_pharm_e_Rx': ''}, {'region': 'National', 'region_code': 'US', 'period': '2011', 'tot_e_Rx': '', 'tot_e_Rx_thru_ehr': '', 'tot_e_Rx_thru_stand_alone': '', 'tot_primary_care_e_Rx': '', 'tot_non_primary_care_e_Rx': '', 'tot_nurse_prac_e_Rx': '', 'tot_phys_asst_e_Rx': '', 'pct_new_renewal_e_Rx': '0.32', 'tot_med_hist_reqs': '', 'tot_med_hist_req_resps': '', 'pct_pharm_enabled': '', 'pct_pharm_e_Rx': ''}, {'region': 'National', 'region_code': 'US', 'period': '2012', 'tot_e_Rx': '', 'tot_e_Rx_thru_ehr': '', 'tot_e_Rx_thru_stand_alone': '', 'tot_primary_care_e_Rx': '', 'tot_non_primary_care_e_Rx': '', 'tot_nurse_prac_e_Rx': '', 'tot_phys_asst_e_Rx': '', 'pct_new_renewal_e_Rx': '0.52', 'tot_med_hist_reqs': '', 'tot_med_hist_req_resps': '', 'pct_pharm_enabled': '', 'pct_pharm_e_Rx': ''}, {'region': 'National', 'region_code': 'US', 'period': '2013', 'tot_e_Rx': '', 'tot_e_Rx_thru_ehr': '', 'tot_e_Rx_thru_stand_alone': '', 'tot_primary_care_e_Rx': '', 'tot_non_primary_care_e_Rx': '', 'tot_nurse_prac_e_Rx': '', 'tot_phys_asst_e_Rx': '', 'pct_new_renewal_e_Rx': '0.57', 'tot_med_hist_reqs': '', 'tot_med_hist_req_resps': '', 'pct_pharm_enabled': '', 'pct_pharm_e_Rx': ''}, {'region': 'National', 'region_code': 'US', 'period': '2008-12', 'tot_e_Rx': '74478', 'tot_e_Rx_thru_ehr': '52947', 'tot_e_Rx_thru_stand_alone': '19182', 'tot_primary_care_e_Rx': '32362', 'tot_non_primary_care_e_Rx': '33445', 'tot_nurse_prac_e_Rx': '6953', 'tot_phys_asst_e_Rx': '3170', 'pct_new_renewal_e_Rx': '', 'tot_med_hist_reqs': '', 'tot_med_hist_req_resps': '', 'pct_pharm_enabled': '0.76', 'pct_pharm_e_Rx': '0.69'}, {'region': 'National', 'region_code': 'US', 'period': '2009-01', 'tot_e_Rx': '81264', 'tot_e_Rx_thru_ehr': '58320', 'tot_e_Rx_thru_stand_alone': '20611', 'tot_primary_care_e_Rx': '', 'tot_non_primary_care_e_Rx': '', 'tot_nurse_prac_e_Rx': '', 'tot_phys_asst_e_Rx': '', 'pct_new_renewal_e_Rx': '', 'tot_med_hist_reqs': '', 'tot_med_hist_req_resps': '', 'pct_pharm_enabled': '', 'pct_pharm_e_Rx': '0.7'}, {'region': 'National', 'region_code': 'US', 'period': '2009-02', 'tot_e_Rx': '88050', 'tot_e_Rx_thru_ehr': '63693', 'tot_e_Rx_thru_stand_alone': '22040', 'tot_primary_care_e_Rx': '', 'tot_non_primary_care_e_Rx': '', 'tot_nurse_prac_e_Rx': '', 'tot_phys_asst_e_Rx': '', 'pct_new_renewal_e_Rx': '', 'tot_med_hist_reqs': '', 'tot_med_hist_req_resps': '', 'pct_pharm_enabled': '', 'pct_pharm_e_Rx': '0.71'}, {'region': 'National', 'region_code': 'US', 'period': '2009-03', 'tot_e_Rx': '94836', 'tot_e_Rx_thru_ehr': '69066', 'tot_e_Rx_thru_stand_alone': '23469', 'tot_primary_care_e_Rx': '', 'tot_non_primary_care_e_Rx': '', 'tot_nurse_prac_e_Rx': '', 'tot_phys_asst_e_Rx': '', 'pct_new_renewal_e_Rx': '', 'tot_med_hist_reqs': '', 'tot_med_hist_req_resps': '', 'pct_pharm_enabled': '', 'pct_pharm_e_Rx': '0.72'}, {'region': 'National', 'region_code': 'US', 'p ...

# %%
#put json data in pandas datafram for better viewing and analyis
usa_df = pd.DataFrame(json_data)
usa_df
# Out:
#         region region_code   period tot_e_Rx tot_e_Rx_thru_ehr  \
# 0     National          US     2008
# 1     National          US     2009
# 2     National          US     2010
# 3     National          US     2011
# 4     National          US     2012
# ...        ...         ...      ...      ...               ...
# 3820   Wyoming          WY  2014-01      996               882
# 3821   Wyoming          WY  2014-02      993               877
# 3822   Wyoming          WY  2014-03     1015               921
# 3823   Wyoming          WY  2014-04     1018               925
# 3824                   NaN      NaN      NaN               NaN
#
#      tot_e_Rx_thru_stand_alone tot_primary_care_e_Rx  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                   ...
# 3820                       113                   492
# 3821                       113                   497
# 3822                        89                   502
# 3823                        90                   503
# 3824                       NaN                   NaN
#
#      tot_non_primary_care_e_Rx tot_nurse_prac_e_Rx tot_phys_asst_e_Rx  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                 ...                ...
# 3820                       496                 134                139
# 3821                       495                 132                142
# 3822                       511                 134                147
# 3823                       511                 135                143
# 3824                       NaN                 NaN                NaN
#
#      pct_new_renewal_e_Rx tot_med_hist_reqs tot_med_hist_req_resps  \
# 0                    0.04
# 1                    0.11
# 2                    0.19
# 3                    0.32
# 4                    0.52
# ...                   ...               ...                    ...
# 3820                                  60060                  51755
# 3821                                  46877                  36895
# 3822                                  66790                  50236
# 3823                                  54765                  38566
# 3824                  NaN               NaN                    NaN
#
#      pct_pharm_enabled pct_pharm_e_Rx
# 0
# 1
# 2
# 3
# 4
# ...                ...            ...
# 3820              0.98           0.97
# 3821              0.98           0.97
# 3822              0.97           0.97
# 3823              0.97           0.97
# 3824               NaN            NaN
#
# [3825 rows x 15 columns]
